# %% [markdown]
# # Welcome to the start of your adventure in Agentic AI

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Are you ready for action??</h2>
#             <span style="color:#ff7800;">Have you completed all the setup steps in the <a href="../setup/">setup</a> folder?<br/>
#             Have you read the <a href="../README.md">README</a>? Many common questions are answered here!<br/>
#             Have you checked out the guides in the <a href="../guides/01_intro.ipynb">guides</a> folder?<br/>
#             Well in that case, you're ready!!
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/tools.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#00bfff;">This code is a live resource - keep an eye out for my updates</h2>
#             <span style="color:#00bfff;">I push updates regularly. As people ask questions or have problems, I add more examples and improve explanations. As a result, the code below might not be identical to the videos, as I've added more steps and better comments. Consider this like an interactive book that accompanies the lectures.<br/><br/>
#             I try to send emails regularly with important updates related to the course. You can find this in the 'Announcements' section of Udemy in the left sidebar. You can also choose to receive my emails via your Notification Settings in Udemy. I'm respectful of your inbox and always try to add value with my emails!
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ### And please do remember to contact me if I can help
#
# And I love to connect: https://www.linkedin.com/in/eddonner/
#
#
# ### New to Notebooks like this one? Head over to the guides folder!
#
# Just to check you've already added the Python and Jupyter extensions to Cursor, if not already installed:
# - Open extensions (View >> extensions)
# - Search for python, and when the results show, click on the ms-python one, and Install it if not already installed
# - Search for jupyter, and when the results show, click on the Microsoft one, and Install it if not already installed
# Then View >> Explorer to bring back the File Explorer.
#
# And then:
# 1. Click where it says "Select Kernel" near the top right, and select the option called `.venv (Python 3.12.9)` or similar, which should be the first choice or the most prominent choice. You may need to choose "Python Environments" first.
# 2. Click in each "cell" below, starting with the cell immediately below this text, and press Shift+Enter to run
# 3. Enjoy!
#
# After you click "Select Kernel", if there is no option like `.venv (Python 3.12.9)` then please do the following:
# 1. On Mac: From the Cursor menu, choose Settings >> VS Code Settings (NOTE: be sure to select `VSCode Settings` not `Cursor Settings`);
# On Windows PC: From the File menu, choose Preferences >> VS Code Settings(NOTE: be sure to select `VSCode Settings` not `Cursor Settings`)
# 2. In the Settings search bar, type "venv"
# 3. In the field "Path to folder with a list of Virtual Environments" put the path to the project root, like C:\Users\username\projects\agents (on a Windows PC) or /Users/username/projects/agents (on Mac or Linux).
# And then try again.
#
# Having problems with missing Python versions in that list? Have you ever used Anaconda before? It might be interferring. Quit Cursor, bring up a new command line, and make sure that your Anaconda environment is deactivated:
# `conda deactivate`
# And if you still have any problems with conda and python versions, it's possible that you will need to run this too:
# `conda config --set auto_activate_base false`
# and then from within the Agents directory, you should be able to run `uv python list` and see the Python 3.12 version.

# %%
# First let's do an import. If you get an Import Error, double check that your Kernel is correct..

from dotenv import load_dotenv

# %%
# Next it's time to load the API keys into environment variables
# If this returns false, see the next cell!

load_dotenv(override=True)
# Out:
# True

# %% [markdown]
# ### Wait, did that just output `False`??
#
# If so, the most common reason is that you didn't save your `.env` file after adding the key! Be sure to have saved.
#
# Also, make sure the `.env` file is named precisely `.env` and is in the project root directory (`agents`)
#
# By the way, your `.env` file should have a stop symbol next to it in Cursor on the left, and that's actually a good thing: that's Cursor saying to you, "hey, I realize this is a file filled with secret information, and I'm not going to send it to an external AI to suggest changes, because your keys should not be shown to anyone else."

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Final reminders</h2>
#             <span style="color:#ff7800;">1. If you're not confident about Environment Variables or Web Endpoints / APIs, please read Topics 3 and 5 in this <a href="../guides/04_technical_foundations.ipynb">technical foundations guide</a>.<br/>
#             2. If you want to use AIs other than OpenAI, like Gemini, DeepSeek or Ollama (free), please see the first section in this <a href="../guides/09_ai_apis_and_ollama.ipynb">AI APIs guide</a>.<br/>
#             3. If you ever get a Name Error in Python, you can always fix it immediately; see the last section of this <a href="../guides/06_python_foundations.ipynb">Python Foundations guide</a> and follow both tutorials and exercises.<br/>
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# Check the key - if you're not using OpenAI, check whichever key you're using! Ollama doesn't need a key.

import os
openai_api_key = os.getenv('OPENAI_API_KEY')

if openai_api_key:
    print(f"OpenAI API Key exists and begins {openai_api_key[:8]}")
else:
    print("OpenAI API Key not set - please head to the troubleshooting guide in the setup folder")
# Out:
# OpenAI API Key exists and begins sk-proj-

# %%
# And now - the all important import statement
# If you get an import error - head over to troubleshooting in the Setup folder
# Even for other LLM providers like Gemini, you still use this OpenAI import - see Guide 9 for why

from openai import OpenAI

# %%
# And now we'll create an instance of the OpenAI class
# If you're not sure what it means to create an instance of a class - head over to the guides folder (guide 6)!
# If you get a NameError - head over to the guides folder (guide 6)to learn about NameErrors - always instantly fixable
# If you're not using OpenAI, you just need to slightly modify this - precise instructions are in the AI APIs guide (guide 9)

openai = OpenAI()

# %%
# Create a list of messages in the familiar OpenAI format

messages = [{"role": "user", "content": "What is 2+2?"}]

# %%
# And now call it! Any problems, head to the troubleshooting guide
# This uses GPT 4.1 nano, the incredibly cheap model
# The APIs guide (guide 9) has exact instructions for using even cheaper or free alternatives to OpenAI
# If you get a NameError, head to the guides folder (guide 6) to learn about NameErrors - always instantly fixable

response = openai.chat.completions.create(
    model="gpt-4.1-nano",
    messages=messages
)

print(response.choices[0].message.content)

# %%
# And now - let's ask for a question:

question = "Please propose a hard, challenging question to assess someone's IQ. Respond only with the question."
messages = [{"role": "user", "content": question}]

# %%
# ask it - this uses GPT 4.1 mini, still cheap but more powerful than nano

response = openai.chat.completions.create(
    model="gpt-4.1-mini",
    messages=messages
)

question = response.choices[0].message.content

print(question)

# %%
# form a new messages list
messages = [{"role": "user", "content": question}]

# %%
# Ask it again

response = openai.chat.completions.create(
    model="gpt-4.1-mini",
    messages=messages
)

answer = response.choices[0].message.content
print(answer)

# %%
from IPython.display import Markdown, display

display(Markdown(answer))

# %% [markdown]
# # Congratulations!
#
# That was a small, simple step in the direction of Agentic AI, with your new environment!
#
# Next time things get more interesting...

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/exercise.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Exercise</h2>
#             <span style="color:#ff7800;">Now try this commercial application:<br/>
#             First ask the LLM to pick a business area that might be worth exploring for an Agentic AI opportunity.<br/>
#             Then ask the LLM to present a pain-point in that industry - something challenging that might be ripe for an Agentic solution.<br/>
#             Finally have 3 third LLM call propose the Agentic AI solution. <br/>
#             We will cover this at up-coming labs, so don't worry if you're unsure.. just give it a try!
#             </span>
#         </td>
#     </tr>
# </table>

# %%
import openai

# FIRST MESSAGE: business area
messages = [
    {"role": "user", "content": "Pick a business area (maybe remodeling) that might be worth exploring for an Agentic AI opportunity."}
]

response = openai.chat.completions.create(
    model="gpt-4o-mini",
    messages=messages
)

business_area = response.choices[0].message.content
print("Business area:", business_area)

# SECOND MESSAGE: ask for painpoint in that area
messages.append({"role": "assistant", "content": business_area})
messages.append({"role": "user", "content": f"Present a pain-point in that industry ({business_area}). Something challenging that might be ripe for an Agentic solution."})

response = openai.chat.completions.create(
    model="gpt-4o-mini",
    messages=messages
)

pain_point = response.choices[0].message.content
print("Pain-point:", pain_point)

# THIRD MESSAGE: add context and help for a proposal
messages.append({"role": "assistant", "content": pain_point})
messages.append({"role": "user", "content": f"Now propose an Agentic AI solution for the problem: {pain_point}"})

response = openai.chat.completions.create(
    model="gpt-4o-mini",
    messages=messages
)

solution = response.choices[0].message.content
print("Agentic AI solution:", solution)
# Out:
# Business area: One promising business area for exploring Agentic AI opportunities is the **home remodeling and renovation industry**. Here are several ways in which Agentic AI could make a significant impact:
#
# ### 1. **Personalized Design Assistance**
#    - **Virtual Design Consultant**: An AI agent could provide personalized interior design or landscaping advice based on user preferences, existing space dimensions, and current trends. Users could interact with the AI through voice or text, receiving instant recommendations and design concepts.
#    - **Augmented Reality Integration**: Leveraging AR, the AI could allow users to visualize changes in real-time, overlaying design changes on their physical spaces through their devices.
#
# ### 2. **Project Management and Scheduling**
#    - **Automated Scheduling**: An AI could manage timelines and schedules, automatically adjusting project timelines based on delays or changes in the scope of work, and notifying clients and contractors accordingly.
#    - **Resource Allocation**: The AI could optimize the allocation of resources such as materials and labor, ensuring that projects remain on budget and are completed efficiently.
#
# ### 3. **Smart Material Recommendations**
#    - **Sourcing Materials**: An intelligent agent could analyze projects and suggest optimal materials based on durability, cost, sustainability, and aesthetic value, as well as establish partnerships with suppliers for direct procurement.
#    - **Sustainability Focus**: The AI could prioritize eco-friendly materials and methods, providing users with options that cater to increasing consumer demand for sustainable practices.
#
# ### 4. **Budget Management**
#    - **Expense Tracking**: By tracking expenses throughout the project, the AI could provide budget forecasts and alerts when costs threaten to exceed the initial estimates.
#    - **Financing Solutions**: The agent could assist clients in exploring financing options and grants available for home renovations, guiding users through applying for these opportunities.
#
# ### 5. **Contractor Matching and Quality Assurance**
#    - **Find the Right Contractor**: Using AI algorithms, the system could match clients with top-rated contractors specialized in their specific type of renovation, factoring in reviews, completion rates, and geographic location.
#    - **Quality Monitoring**: Employing machine learning, the AI could analyze project completion reports and user feedback to continuously evaluate contractor performance and recommend the best options.
#
# ### 6. **Client Communication and Support**
#    - **Chatbot Support**: An AI chatbot could handle customer inquiries, providing real-time support for clients who have questions during any stage of their remodeling project.
#    - **Feedback and Improvement**: After project completion, the AI could follow up with clients to gather feedback, analyze satisfaction rates, and use the insights to recommend improvements to contractors.
#
# ### 7. **Predictive Maintenance and Future Planning**
#    - **Home Health Monitoring**: The AI could integrate with smart home technologies to analyze the condition of the home over time, predicting when renovations or maintenance will be necessary based on usage patterns and deterioration rates.
#    - **Future Renovation Planning**: Over time, the AI could learn from user preferences and trends to suggest future renovations, enhancing property value or improving livability in line with changing family dynamics or lifestyles.
#
# By leveraging Agentic AI across these various facets of the home remodeling industry, businesses can enhance customer experiences, streamline operations, and foster more efficient and sustainable practices.
# Pain-point: ### Pain Point: **Inconsistent Contractor Quality and Communication**
#
# **Challenge Overview:**
# Homeowners often face significant challenges when selecting contractors for remodeling projects. The process can be fraught with issues such as inconsistent quality of work, ineffective communication, delays, and unexpected costs. Many homeowners have trouble verifying the credentials and reliability of contractors, leading to a stressful experience and potentially disappointing outcomes.
#
# ### Key Aspects of the Pain Point:
#
# 1. **Quality Variation**:
#    - Not all contractors provide the same level of quality, and even highly-reviewed ones may deliver inconsistent results. Homeowners often do not have adequate systems in place to pre-screen or monitor contractor performance.
#
# 2. **Communication Breakdowns**:
#    - Miscommunication can lead to misunderstandings about project scope, timelines, and costs. Homeowners frequently report feeling out of the loop, leading to frustration and mistrust.
#
# 3. **Project Delays and Budget Overruns**:
#    - Delays in project completion and unexpected costs are common, often stemming from poor planning, mismanagement of resources, or unforeseen circumstances. This unpredictability can strain relationships between homeowners and contractors.
#
# 4. **Difficulty in Finding the Right Match**:
#    - Homeowners often struggle to find contractors who not only meet their needs in terms of skills and specialties but are also reliable and trustworthy. An overload of options, combined with limited information, can lead to analysis paralysis.
#
# ### Opportunity for Agentic AI Solutions:
#
# An Agentic AI could tackle these challenges effectively by:
#
# 1. **Smart Contractor Matching**:
#    - Implement an AI-driven contractor matching system that considers a range of factors including past performance metrics, customer reviews, specific project needs, and geographic location to connect homeowners with the best potential contractors.
#
# 2. **Real-Time Quality Monitoring**:
#    - Utilize machine learning algorithms that analyze ongoing project data, such as timelines and budget adherence, coupled with client feedback, to provide real-time performance insights. This could help identify any issues before they escalate and create a quality assurance feedback loop.
#
# 3. **Automated Communication Portal**:
#    - Develop a communication platform powered by AI that keeps all parties informed. This could include automatic updates on project status, reminders for scheduled meetings, and responses to common inquiries through a chatbot, reducing communication gaps.
#
# 4. **Predictive Analytics for Project Management**:
#    - Use AI to forecast potential delays and budget issues by analyzing historical data and current project conditions. The system could provide alerts and suggestions on how to mitigate these risks based on previous projects.
#
# 5. **Feedback and Reputation System**:
#    - Implement a dynamic feedback system where clients can rate contractors in real-time, contributing to a living reputation score. This data could also be used to inform future contracts and improve contractor performance.
#
# By addressing these pain points through an Agentic AI solution, the home remodeling industry can streamline processes, enhance the quality of work, improve client-contractor relationships, and ultimately create a more positive experience for homeowners undertaking renovation projects.
# Agentic AI solution: ### Proposed Agentic AI Solution for Inconsistent Contractor Quality and Communication
#
# #### Solution Name: **RenovateSmart**
#
# ### Overview:
# RenovateSmart is an intelligent platform designed to connect homeowners with contractors, ensuring quality work, streamlined communication, and effective project management. By leveraging advanced AI technologies, RenovateSmart addresses the pain points of inconsistent contractor quality, communication breakdowns, project delays, and difficulties in finding the right match.
#
# ### Key Features of RenovateSmart:
#
# 1. **Smart Contractor Matching Engine**:
#    - **AI-Powered Algorithm**: The platform will utilize a robust matching algorithm that considers a contractor’s skills, specialization, past performance (including historical project outcomes, ratings, and completion times), and geographic proximity to connect homeowners with the best-suited contractors.
#    - **Client Requirements Analysis**: Homeowners enter their specific project requirements, budget, and preferences. The AI analyzes these inputs and returns a curated list of contractors, complete with profiles and portfolios.
#
# 2. **Real-Time Quality Monitoring and Reporting**:
#    - **Performance Metrics Dashboard**: Contractors will be monitored through a dashboard displaying real-time performance metrics, including adherence to timelines, budget control, and quality of work based on client feedback.
#    - **Automated Alerts**: If a project begins to deviate from the agreed plan, the system will send alerts to both the contractor and homeowner, allowing for timely intervention.
#
# 3. **AI-Driven Communication Hub**:
#    - **Centralized Communication Portal**: A dedicated chat interface will facilitate seamless communication between homeowners and contractors, allowing both parties to exchange updates, documents, and videos/photos of the work in progress.
#    - **Automated Updates and Reminders**: The system will automatically schedule and send reminders for project milestones, changes, or upcoming meetings, ensuring all participants stay informed.
#
# 4. **Predictive Project Management Tools**:
#    - **Risk Assessment Module**: By analyzing historical data, the AI can proactively assess risks associated with each project, hinting at potential delays and budget overruns based on similar past projects.
#    - **Scenario Planning**: The AI will suggest alternative timelines or budget adjustments based on real-time data, helping homeowners and contractors adapt to any emerging challenges.
#
# 5. **Dynamic Feedback and Reputation System**:
#    - **Real-Time Rating System**: After each significant project milestone, clients can provide feedback. The system will assign real-time reputation scores to contractors based on client reviews, performance metrics, and timeliness.
#    - **Community Insights**: Contractors can improve their services by viewing aggregate feedback and suggestions, creating a culture of transparent communication and quality enhancement.
#
# 6. **Integrated Payment and Contract Management**:
#    - **Secure Transaction Handling**: RenovateSmart will offer secure payment solutions with milestone-based payments linked to project completion, reducing financial disputes.
#    - **Contract Management Tools**: The platform will include templates for contracts that can be customized and digitally signed, ensuring all parties are clear about the project scope and obligations.
#
# ### Implementation and Benefits:
# - **User-Friendly Interface**: RenovateSmart will feature an intuitive interface for homeowners and contractors, making it easy to navigate through features.
# - **Continuous Learning**: The AI will learn from ongoing projects, continuously refining its matching algorithm and predictive analytics to improve future experiences.
# - **Enhanced Satisfaction**: By providing a reliable and transparent platform, RenovateSmart aims to alleviate homeowners’ stress and uncertainty while simultaneously empowering contractors to deliver high-quality results consistently.
#
# ### Conclusion:
# RenovateSmart stands to revolutionize the home remodeling and renovation industry by directly addressing the critical challenges of inconsistent contractor quality and communication. Through intelligent matching, real-time performance monitoring, and effective communication, this Agentic AI solution fosters a more trustworthy and efficient remodeling experience for both homeowners and contractors.

# %%
from IPython.display import Markdown, display

display(Markdown(solution))
# Out:
# ### Proposed Agentic AI Solution for Inconsistent Contractor Quality and Communication
#
# #### Solution Name: **RenovateSmart**
#
# ### Overview:
# RenovateSmart is an intelligent platform designed to connect homeowners with contractors, ensuring quality work, streamlined communication, and effective project management. By leveraging advanced AI technologies, RenovateSmart addresses the pain points of inconsistent contractor quality, communication breakdowns, project delays, and difficulties in finding the right match.
#
# ### Key Features of RenovateSmart:
#
# 1. **Smart Contractor Matching Engine**:
#    - **AI-Powered Algorithm**: The platform will utilize a robust matching algorithm that considers a contractor’s skills, specialization, past performance (including historical project outcomes, ratings, and completion times), and geographic proximity to connect homeowners with the best-suited contractors.
#    - **Client Requirements Analysis**: Homeowners enter their specific project requirements, budget, and preferences. The AI analyzes these inputs and returns a curated list of contractors, complete with profiles and portfolios.
#
# 2. **Real-Time Quality Monitoring and Reporting**:
#    - **Performance Metrics Dashboard**: Contractors will be monitored through a dashboard displaying real-time performance metrics, including adherence to timelines, budget control, and quality of work based on client feedback.
#    - **Automated Alerts**: If a project begins to deviate from the agreed plan, the system will send alerts to both the contractor and homeowner, allowing for timely intervention.
#
# 3. **AI-Driven Communication Hub**:
#    - **Centralized Communication Portal**: A dedicated chat interface will facilitate seamless communication between homeowners and contractors, allowing both parties to exchange updates, documents, and videos/photos of the work in progress.
#    - **Automated Updates and Reminders**: The system will automatically schedule and send reminders for project milestones, changes, or upcoming meetings, ensuring all participants stay informed.
#
# 4. **Predictive Project Management Tools**:
#    - **Risk Assessment Module**: By analyzing historical data, the AI can proactively assess risks associated with each project, hinting at potential delays and budget overruns based on similar past projects.
#    - **Scenario Planning**: The AI will suggest alternative timelines or budget adjustments based on real-time data, helping homeowners and contractors adapt to any emerging challenges.
#
# 5. **Dynamic Feedback and Reputation System**:
#    - **Real-Time Rating System**: After each significant project milestone, clients can provide feedback. The system will assign real-time reputation scores to contractors based on client reviews, performance metrics, and timeliness.
#    - **Community Insights**: Contractors can improve their services by viewing aggregate feedback and suggestions, creating a culture of transparent communication and quality enhancement.
#
# 6. **Integrated Payment and Contract Management**:
#    - **Secure Transaction Handling**: RenovateSmart will offer secure payment solutions with milestone-based payments linked to project completion, reducing financial disputes.
#    - **Contract Management Tools**: The platform will include templates for contracts that can be customized and digitally signed, ensuring all parties are clear about the project scope and obligations.
#
# ### Implementation and Benefits:
# - **User-Friendly Interface**: RenovateSmart will feature an intuitive interface for homeowners and contractors, making it easy to navigate through features.
# - **Continuous Learning**: The AI will learn from ongoing projects, continuously refining its matching algorithm and predictive analytics to improve future experiences.
# - **Enhanced Satisfaction**: By providing a reliable and transparent platform, RenovateSmart aims to alleviate homeowners’ stress and uncertainty while simultaneously empowering contractors to deliver high-quality results consistently.
#
# ### Conclusion:
# RenovateSmart stands to revolutionize the home remodeling and renovation industry by directly addressing the critical challenges of inconsistent contractor quality and communication. Through intelligent matching, real-time performance monitoring, and effective communication, this Agentic AI solution fosters a more trustworthy and efficient remodeling experience for both homeowners and contractors.
